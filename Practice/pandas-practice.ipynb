# %%
import pandas as pd

data = {
    "time": [40, 30, 35],
    "speed": [10, 15, 12]
}

df = pd.DataFrame(data)
print(dataFrame)
# Out:
#    time  speed
# 0    40     10
# 1    30     15
# 2    35     12

# %%
#Locate Row
print(df.loc[0])
# Out:
# time     40
# speed    10
# Name: 0, dtype: int64

# %%
#Locate Column
print(df.loc[[0, 1]])
# Out:
#    time  speed
# 0    40     10
# 1    30     15

# %%
#Change the index
df = pd.DataFrame(data, index=["First runner", "Second runner", "Third runner"])
print(df)
# Out:
#                time  speed
# First runner     40     10
# Second runner    30     15
# Third runner     35     12

# %%
#Locate index
print(df.loc["Second runner"])
# Out:
# time     30
# speed    15
# Name: Second runner, dtype: int64
